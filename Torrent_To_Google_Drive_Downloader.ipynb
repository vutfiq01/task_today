# %% [markdown]
# <a href="https://colab.research.google.com/github/vutfiq01/task_today/blob/main/Torrent_To_Google_Drive_Downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Torrent To Google Drive Downloader

# %% [markdown]
# **Important Note:** To get more disk space:
# > Go to Runtime -> Change Runtime and give GPU as the Hardware Accelerator.  You will get around 384GB to download any torrent you want.

# %%
# !apt-get -y install aria2

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

# Create the Torrents folder if it doesn't exist
download_path = '/content/drive/My Drive/Torrents'
os.makedirs(download_path, exist_ok=True)

# %%
# Replace the link below with your actual magnet link
# !aria2c --dir="/content/drive/My Drive/Torrents" --seed-time=0 "YOUR_MAGNET_LINK_HERE"
